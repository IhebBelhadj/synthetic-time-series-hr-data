# %%
import os
import pandas as pd
import numpy as np

# %%
CONFIG = {
    'data_dir': "../data",
}

# %%
file_path = os.path.join(CONFIG['data_dir'], 'attrition.csv')

# %%
df = pd.read_csv(file_path)

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['YearsAtCompany'].value_counts().sort_index(ascending=True)
# Out:
# YearsAtCompany
# 0      44
# 1     171
# 2     127
# 3     128
# 4     110
# 5     196
# 6      76
# 7      90
# 8      80
# 9      82
# 10    120
# 11     32
# 12     14
# 13     24
# 14     18
# 15     20
# 16     12
# 17      9
# 18     13
# 19     11
# 20     27
# 21     14
# 22     15
# 23      2
# 24      6
# 25      4
# 26      4
# 27      2
# 29      2
# 30      1
# 31      3
# 32      3
# 33      5
# 34      1
# 36      2
# 37      1
# 40      1
# Name: count, dtype: int64

# %%
df['StockOptionLevel'].value_counts()
# Out:
# StockOptionLevel
# 0    631
# 1    596
# 2    158
# 3     85
# Name: count, dtype: int64

# %%
df['PercentSalaryHike'].value_counts()
# Out:
# PercentSalaryHike
# 11    210
# 13    209
# 14    201
# 12    198
# 15    101
# 18     89
# 17     82
# 16     78
# 19     76
# 22     56
# 20     55
# 21     48
# 23     28
# 24     21
# 25     18
# Name: count, dtype: int64

# %%
df['MonthlyIncome'].value_counts().sort_index(ascending=False)
# Out:
# MonthlyIncome
# 19999    1
# 19973    1
# 19943    1
# 19926    1
# 19859    1
#         ..
# 1091     1
# 1081     1
# 1052     1
# 1051     1
# 1009     1
# Name: count, Length: 1349, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# JobRole
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: count, dtype: int64

# %%
combo_counts = df.groupby(['JobRole', 'JobLevel', 'Department']).size().reset_index(name='Count')
combo_counts
# Out:
#                       JobRole  JobLevel              Department  Count
# 0   Healthcare Representative         2  Research & Development     78
# 1   Healthcare Representative         3  Research & Development     44
# 2   Healthcare Representative         4  Research & Development      9
# 3             Human Resources         1         Human Resources     33
# 4             Human Resources         2         Human Resources     13
# 5             Human Resources         3         Human Resources      6
# 6       Laboratory Technician         1  Research & Development    200
# 7       Laboratory Technician         2  Research & Development     56
# 8       Laboratory Technician         3  Research & Development      3
# 9                     Manager         3  Research & Development      8
# 10                    Manager         3                   Sales      4
# 11                    Manager         4         Human Resources      4
# ...

# %%
df['EnvironmentSatisfaction'].value_counts()
# Out:
# EnvironmentSatisfaction
# 3    453
# 4    446
# 2    287
# 1    284
# Name: count, dtype: int64

# %%
df['JobSatisfaction'].value_counts()
# Out:
# JobSatisfaction
# 4    459
# 3    442
# 1    289
# 2    280
# Name: count, dtype: int64
